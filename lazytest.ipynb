# %%
from lazypredict.Supervised import LazyClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
import pandas as pd

# %% [markdown]
# ata = load_breast_cancer()

# %%
#data = pd.read_csv("ACME-HappinessSurvey2020.csv")
data = pd.read_csv("Inverted-Survey.csv")
#X = data.data
X = data.drop(columns=["Y"])
#y = data.target
y = data["Y"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=123)

# %%
clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
models, predictions = clf.fit(X_train, X_test, y_train, y_test)

# %%
print(models)
# Out:
#                                Accuracy  Balanced Accuracy   ROC AUC  \
# Model
# PassiveAggressiveClassifier    0.634921           0.607143  0.586735
# DecisionTreeClassifier         0.619048           0.603571  0.595918
# KNeighborsClassifier           0.587302           0.567857  0.525000
# NuSVC                          0.571429           0.557143  0.589796
# SGDClassifier                  0.555556           0.553571  0.556122
# ExtraTreeClassifier            0.555556           0.528571  0.508163
# BaggingClassifier              0.539683           0.517857  0.593878
# CalibratedClassifierCV         0.539683           0.510714  0.537755
# LogisticRegression             0.523810           0.510714  0.533673
# RandomForestClassifier         0.523810           0.503571  0.591327
# DummyClassifier                0.555556           0.500000  0.500000
# LabelSpreading                 0.507937           0.496429  0.526020
# LabelPropagation               0.507937           0.496429  0.547449
# ExtraTreesClassifier           0.507937           0.482143  0.593878
# NearestCentroid                0.492063           0.478571  0.551020
# LinearSVC                      0.492063           0.475000  0.538776
# LinearDiscriminantAnalysis     0.492063           0.475000  0.538265
# RidgeClassifierCV              0.492063           0.475000  0.537755
# RidgeClassifier                0.492063           0.475000  0.538265
# AdaBoostClassifier             0.476190           0.464286  0.486224
# BernoulliNB                    0.476190           0.460714  0.563265
# SVC                            0.460317           0.450000  0.539796
# GaussianNB                     0.460317           0.446429  0.507143
# QuadraticDiscriminantAnalysis  0.460317           0.446429  0.489796
# Perceptron                     0.444444           0.432143  0.393878
#
#                                F1 Score  Precision    Recall  Time Taken
# Model
# PassiveAggressiveClassifier    0.608325   0.643519  0.634921    0.020972
# DecisionTreeClassifier         0.611228   0.614930  0.619048    0.022235
# KNeighborsClassifier           0.574074   0.580362  0.587302    0.015205
# NuSVC                          0.564706   0.565217  0.571429    0.022032
# SGDClassifier                  0.556682   0.558923  0.555556    0.016170
# ExtraTreeClassifier            0.527470   0.541371  0.555556    0.021411
# BaggingClassifier              0.521830   0.526183  0.539683    0.030353
# CalibratedClassifierCV         0.506149   0.519907  0.539683    0.042036
# LogisticRegression             0.518365   0.517094  0.523810    0.020140
# RandomForestClassifier         0.508547   0.510078  0.523810    0.124586
# DummyClassifier                0.396825   0.308642  0.555556    0.020664
# LabelSpreading                 0.504121   0.502573  0.507937    0.014657
# LabelPropagation               0.504121   0.502573  0.507937    0.014755
# ExtraTreesClassifier           0.481207   0.484939  0.507937    0.110875
# NearestCentroid                0.486255   0.484330  0.492063    0.022044
# LinearSVC                      0.481637   0.479921  0.492063    0.014129
# LinearDiscriminantAnalysis     0.481637   0.479921  0.492063    0.014288
# RidgeClassifierCV              0.481637   0.479921  0.492063    0.016951
# RidgeClassifier                0.481637   0.479921  0.492063    0.016900
# AdaBoostClassifier             0.472129   0.470175  0.476190    0.077828
# BernoulliNB                    0.467974   0.465580  0.476190    0.014848
# SVC                            0.457819   0.456225  0.460317    0.017061
# GaussianNB                     0.454146   0.451567  0.460317    0.014255
# QuadraticDiscriminantAnalysis  0.454146   0.451567  0.460317    0.020589
# Perceptron                     0.440137   0.437778  0.444444    0.021024

# %%
#print("predictions is ", predictions)
