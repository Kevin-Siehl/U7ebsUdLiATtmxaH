# %%
#accuracyPA = []
#accuracyKN = []
#accuracyDT = []
# %store -r

# %%
precision0PA = []
precision0KN = []
precision0DT = []

# %%
recall0PA = []
recall0KN = []
recall0DT = []

# %%
fscore0PA = []
fscore0KN = []
fscore0DT = []

# %%
precision1PA = []
precision1KN = []
precision1DT = []

# %%
recall1PA = []
recall1KN = []
recall1DT = []

# %%
fscore1PA = []
fscore1KN = []
fscore1DT = []

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

import random
import math

# %%
# Load data
data = pd.read_csv("ACME-HappinessSurvey2020.csv")

# Separate features and target
X = data.drop("Y", axis=1)
y = data["Y"]

# %%
test_split_seed = random.randrange(1000,9999)
print(test_split_seed)

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    random_state=test_split_seed
)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
# Out:
# 2904

# %%
#init_seed = random.randrange(1000,9999)
#print(init_seed)

# %%
modelPA = PassiveAggressiveClassifier(
    C=0.05, #0.1,
    loss="squared_hinge",
    #loss="hinge",
    early_stopping=True,
    #class_weight=None,
    class_weight="balanced",
    average=True,
    #random_state=init_seed,
    random_state=1234,
    tol=0.1
)
# Train
modelPA.fit(X_train, y_train)
# Out:
# /data/Apziva/venv/lib/python3.12/site-packages/sklearn/utils/deprecation.py:71: FutureWarning: Class PassiveAggressiveClassifier is deprecated; this is deprecated in version 1.8 and will be removed in 1.10. Use `SGDClassifier(loss='hinge', penalty=None, learning_rate='pa1', eta0=1.0)` instead.
#   warnings.warn(msg, category=FutureWarning)
# /data/Apziva/venv/lib/python3.12/site-packages/sklearn/utils/deprecation.py:71: FutureWarning: Class PassiveAggressiveClassifier is deprecated; this is deprecated in version 1.8 and will be removed in 1.10. Use `SGDClassifier(loss='hinge', penalty=None, learning_rate='pa1', eta0=1.0)` instead.
#   warnings.warn(msg, category=FutureWarning)
# PassiveAggressiveClassifier(C=0.05, average=True, class_weight='balanced',
#                             early_stopping=True, loss='squared_hinge',
#                             random_state=1234, tol=0.1)

# %%
# -----------------------------
# Create and train model
# -----------------------------
ModelKNN = KNeighborsClassifier(
    n_neighbors=5,
    weights='uniform',
    metric='minkowski',
    p=1
)

ModelKNN.fit(X_train_scaled, y_train)
# Out:
# KNeighborsClassifier(p=1)

# %%
# Create model
modelD = DecisionTreeClassifier(
    max_depth=None, #3,10,5  #default=none
    random_state=1234,
    #random_state=init_seed,
    min_samples_split=2, #10 #default=2
    max_leaf_nodes=None,
    min_samples_leaf=5, #5  #default=1
    class_weight=None, #"balanced"
    criterion = "log_loss" # "entropy", "log_loss", default="gini"
)

# Train model
modelD.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='log_loss', min_samples_leaf=5,
#                        random_state=1234)

# %%
# Predict
y_predPA = modelPA.predict(X_test)

print(accuracy_score(y_test, y_predPA))

accuracyPA.append(accuracy_score(y_test, y_predPA))
print(confusion_matrix(y_test, y_predPA))
print(classification_report(y_test, y_predPA))
print(test_split_seed)
# Out:
# 0.5
# [[5 4]
#  [9 8]]
#               precision    recall  f1-score   support
#
#            0       0.36      0.56      0.43         9
#            1       0.67      0.47      0.55        17
#
#     accuracy                           0.50        26
#    macro avg       0.51      0.51      0.49        26
# weighted avg       0.56      0.50      0.51        26
#
# 2904

# %%
y_predKNN = ModelKNN.predict(X_test_scaled)

# -----------------------------
# Evaluation
# -----------------------------
print("Accuracy:", accuracy_score(y_test, y_predKNN))
accuracyKN.append(accuracy_score(y_test, y_predKNN))

print("\nClassification Report:")
print(classification_report(y_test, y_predKNN))

print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_predKNN))
print(test_split_seed)
# Out:
# Accuracy: 0.46153846153846156
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.22      0.22      0.22         9
#            1       0.59      0.59      0.59        17
#
#     accuracy                           0.46        26
#    macro avg       0.41      0.41      0.41        26
# weighted avg       0.46      0.46      0.46        26
#
#
# Confusion Matrix:
# [[ 2  7]
#  [ 7 10]]
# 2904

# %%
# Make predictions
y_predD = modelD.predict(X_test)

# Evaluate
print("Accuracy:", accuracy_score(y_test, y_predD))
accuracyDT.append(accuracy_score(y_test, y_predD))

print("\nClassification Report:")
print(classification_report(y_test, y_predD))

print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_predD))
print(test_split_seed)
# Out:
# Accuracy: 0.46153846153846156
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.33      0.56      0.42         9
#            1       0.64      0.41      0.50        17
#
#     accuracy                           0.46        26
#    macro avg       0.48      0.48      0.46        26
# weighted avg       0.53      0.46      0.47        26
#
#
# Confusion Matrix:
# [[ 5  4]
#  [10  7]]
# 2904

# %%
#seed 1411 gives good results recall = 0.62 dec10,3,4,9 pa5867,6767

# %%
sum_ = 0
for PA in accuracyPA:
    sum_ += PA
avgPA = sum_ / len(accuracyPA)
print("number of trials: ", len(accuracyPA))
print("average value: ", avgPA)
# Out:
# number of trials:  7
# average value:  0.5274725274725275

# %%
sum_ = 0
for DT in accuracyDT:
    sum_ += DT
avgDT = sum_ / len(accuracyDT)
print("number of trials: ", len(accuracyDT))
print("average value: ", avgDT)
# Out:
# number of trials:  7
# average value:  0.5714285714285714

# %%
sum_ = 0
for KN in accuracyKN:
    sum_ += KN
avgKN = sum_ / len(accuracyKN)
print("number of trials: ",len(accuracyKN))
print("average value: ", avgKN)
# Out:
# number of trials:  7
# average value:  0.5604395604395603

# %%
sum_ = 0
for DT in accuracyDT:
    sum_ += (avgDT-DT)*(avgDT-DT)
std_devDT = math.sqrt(sum_ / len(accuracyDT))
print("number of trials: ",len(accuracyDT))
print("standard deviation: ", std_devDT)
# Out:
# number of trials:  7
# standard deviation:  0.08582691951545773

# %%
sum_ = 0
for PA in accuracyPA:
    sum_ += (avgPA-PA)*(avgPA-PA)
std_devPA = math.sqrt(sum_ / len(accuracyPA))
print("number of trials: ",len(accuracyPA))
print("standard deviation: ", std_devPA)
# Out:
# number of trials:  7
# standard deviation:  0.09128158091118763

# %%
sum_ = 0
for KN in accuracyKN:
    sum_ += (avgKN-KN)*(avgKN-KN)
std_devKN = math.sqrt(sum_ / len(accuracyKN))
print("number of trials: ",len(accuracyKN))
print("standard deviation: ", std_devKN)
# Out:
# number of trials:  7
# standard deviation:  0.1104381936386911

# %%
# %store accuracyPA
# Out:
# Stored 'accuracyPA' (list)

# %%
# %store accuracyKN
# Out:
# Stored 'accuracyKN' (list)

# %%
# %store accuracyDT
# Out:
# Stored 'accuracyDT' (list)

# %%
print(accuracyPA)
# Out:
# [0.4230769230769231, 0.38461538461538464, 0.5384615384615384, 0.6153846153846154, 0.5769230769230769, 0.6538461538461539, 0.5]

# %%
print(accuracyKN)
# Out:
# [0.38461538461538464, 0.5769230769230769, 0.5769230769230769, 0.5769230769230769, 0.5769230769230769, 0.7692307692307693, 0.46153846153846156]

# %%
print(accuracyDT)
# Out:
# [0.6538461538461539, 0.46153846153846156, 0.6153846153846154, 0.6538461538461539, 0.5, 0.6538461538461539, 0.46153846153846156]
